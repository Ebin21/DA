# %%
from pandas import DataFrame

# %%
data={'name':['Ebin', 'Alex'],
     'age':[25,64],
     'salary' : [25, 10]}

# %%
frame=DataFrame(data)
frame
# Out:
#    name  age  salary
# 0  Ebin   25      25
# 1  Alex   64      10

# %%
newframe=DataFrame(data, columns=['name','salary', 'age'])
newframe
# Out:
#    name  salary  age
# 0  Ebin      25   25
# 1  Alex      10   64

# %%
newframe.loc[1]
# Out:
# name      Alex
# salary      10
# age         64
# Name: 1, dtype: object

# %%
newframe['profile']='IT', 'tailor'
newframe['edu']='BCA', '10'
newframe
# Out:
#    name  salary  age profile  edu
# 0  Ebin      25   25      IT  BCA
# 1  Alex      10   64  tailor   10

# %%
newframe.drop('edu', axis=1, inplace=True)

# %%
newframe.loc[len(newframe)] = ["Stella Alex", 35, 50, "House Wife"]

# %%
newframe
# Out:
#           name  salary  age     profile
# 0         Ebin      25   25          IT
# 1         Alex      10   64      tailor
# 2  Stella Alex      35   50  House Wife

# %%
newframe
# Out:
#           name  salary  age     profile
# 0         Ebin      25   25          IT
# 1         Alex      10   64      tailor
# 2  Stella Alex      35   50  House Wife

# %%
from pandas import Series
obj=Series([1,2,3], index=['a','b','c'])

# %%
obj
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj=obj.reindex(['a','c','b'])

# %%
obj
# Out:
# a    1
# c    3
# b    2
# dtype: int64
