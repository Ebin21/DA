# %%
from pandas import Series
se=Series([1,2,3,5,4])

# %%
se
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    4
# dtype: int64

# %%
sed=Series([1,2,3], index=['a','b','c'])
sed
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
se.sort_values
# Out:
# <bound method Series.sort_values of 0    1
# 1    2
# 2    3
# 3    5
# 4    4
# dtype: int64>

# %%
se+sed
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# a   NaN
# b   NaN
# c   NaN
# dtype: float64
