# %%
import numpy as np

u = np.array([1,0])
v = np.array([0,1])
z=u + v
print(z)
# Out:
# [1 1]

# %%
u = np.array([1,0])
v = np.array([0,1])
z=[]
for n, m in zip(u,v):
    z.append(n+m)
print(z)
# Out:
# [np.int64(1), np.int64(1)]
