# %%
import pandas as pd
sales=pd.read_csv('sales.csv')

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales['Invoice ID'].unique()
# Out:
# array([460489604, 471006167, 411909258, 487313402, 197763430, 263634050,
#         99646662, 188869875, 325637547, 562942936, 388412668, 846531724,
#        149894432, 942406749, 547572603, 355981315, 397754805,  90524319,
#        542144906, 729486362, 619639105, 443198801, 761515143,  56578535,
#        834838148, 833288071, 508614950, 103072863, 355815500, 193855414,
#        600792216, 567867755, 597934753, 419033295,   8795029, 912473338,
#        209725428, 460044751, 191736512, 979973145,  43371182, 613811022,
#        673603546, 328132417, 325924536, 747705702, 450817216, 315624039,
#        888822600, 896399395,  20548577, 500850764, 466598448, 265371038,
#        175938157, 839600262, 885253494, 180545139, 227063423, 500777576,
#        426576006, 934647292, 975443414, 858716993, 776761484, 798252244,
#        595065138, 366083315, 746011173, 687132774, 554361739, 563130623,
#        380354826, 107399414, 851267575, 437093770, 177764380,  36054637,
# ...

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales.iloc[200:205]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# 202  Groceries     22         7    154    Card       5
# 203      Books     95         6    570    Card       1
# 204   Clothing     69         2    138    Cash       2

# %%
sales[sales['Gender']=='Female'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14   547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 15   355981315  2/15/2018  15:47  Female   Brookfield  NewYork    Yes
# 16   397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 3    Sporting     89         4    356    Gpay       1
# ...

# %%
sales[sales['Payment']=='Cash'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6     99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 12   149894432  1/12/2018  11:12    Male    Park lane   Dallas     No
# 17    90524319  3/19/2018  18:18    Male    Park lane   Dallas    Yes
# 19   729486362   3/7/2018  12:50    Male  Water tower  Chicago     No
# 20   619639105  3/26/2018  19:48  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
sales[sales['City']=='NewYork'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender    Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5    263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10   388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14   547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15   355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# 16   397754805   2/9/2018  15:59  Female  Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female  Brookfield  NewYork    Yes
# 20   619639105  3/26/2018  19:48  Female  Brookfield  NewYork     No
# 21   443198801  2/24/2018  19:31  Female  Brookfield  NewYork     No
# 24   834838148  2/15/2018  13:00    Male  Brookfield  NewYork    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 5    Clothing     52         4    208    Gpay       3
# ...

# %%
sales['Category'].unique()
# Out:
# <StringArray>
# ['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books', 'Furniture']
# Length: 6, dtype: str

# %%
sales[(sales['Total']>100) & (sales['Total']<200)].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11   846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
# 19   729486362   3/7/2018  12:50    Male  Water tower  Chicago     No
# 32   597934753  3/26/2018  16:46  Female   Brookfield  NewYork     No
# 33   419033295  3/24/2018  15:57    Male  Water tower  Chicago    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
sales.sum()["Total"]
# Out:
# np.int64(207788)

# %%
sales.max()["Quantity"]
# Out:
# np.int64(7)

# %%
sales[sales['Total'] == sales['Total'].max()]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales["Total"] = pd.to_numeric(sales["Total"], errors='coerce')

# %%
cols_to_convert = ['Total', 'Quantity', 'Price']
for col in cols_to_convert:
    sales[col] = pd.to_numeric(sales[col], errors='coerce')

# %%
sales.mean(numeric_only=True)["Total"]
# Out:
# np.float64(207.788)

# %%
sales[sales['Total'] == sales['Total'].min()]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales.groupby('City').sum(numeric_only=True)
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sales.groupby('Date').sum(numeric_only=True)
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# Date
# 1/1/2018   5754968491    722        42   2649      45
# 1/10/2018  5071442922    433        27   1116      25
# 1/11/2018  4596704479    397        34   1562      20
# 1/12/2018  5999941284    603        44   2625      36
# 1/13/2018  6152497894    435        50   2340      26
# ...               ...    ...       ...    ...     ...
# 3/5/2018   7176403264   1001        76   4616      48
# 3/6/2018   4759166414    459        50   1915      35
# 3/7/2018   5519232431    237        42   1048      24
# 3/8/2018   5365615999    759        38   2638      33
# 3/9/2018   6478665906    882        72   4300      48
#
# [89 rows x 5 columns]

# %%
sales.groupby('Gender').sum(numeric_only=True)['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').sum()['Payment']
# Out:
# Gender
# Female    CardGpayCashCashGpayGpayGpayCardGpayGpayCashCa...
# Male      CashCashGpayCashCashCardCardCashCashCashGpayCa...
# Name: Payment, dtype: str

# %%
location_list = sales.groupby('Location')
location=[x for x,y in location_list]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum(numeric_only=True)['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.bar(location, sales.groupby('Location').sum(numeric_only=True)['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum(numeric_only=True)['Total'], labels=location, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x289abcb9400>,
# ...
#  [Text(0.5080358105176171, 0.9756534298774888, 'Brookfield'),
#   Text(-1.0939745542483426, -0.11497684400408782, 'Park lane'),
#   Text(0.6072326270595838, -0.9172069213837827, 'Water tower')],
#  [Text(0.27711044210051844, 0.5321745981149938, '34.7%'),
#   Text(-0.5967133932263686, -0.06271464218404789, '33.9%'),
#   Text(0.3312177965779548, -0.5002946843911541, '31.4%')])

# %%
location_sales = sales.groupby(['Gender', 'Location']).count()['Invoice ID']
location_sales
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
unstacked_location_sales = location_sales.unstack(level=0)

# %%
unstacked_location_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
sales['Day'] = pd.to_datetime(sales['Date']).dt.day
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# ...

# %%
day_sales = sales.groupby('Day').sum(numeric_only=True)['Total']
day_sales.plot(kind='line')
# Out:
# <Axes: xlabel='Day'>

# %%
sales.head(1)
# Out:
#    Invoice ID       Date   Time Gender    Location     City Member   Category  \
# 0   460489604  1/25/2018  16:46   Male  Brookfield  NewYork    Yes  Groceries
#
#    Price  Quantity  Total Payment  Rating  Day
# 0     30         1     30    Cash       2   25

# %%
Members = sales.groupby(['Member', 'Location']).count()['Invoice ID']
Members.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
rating = sales.groupby(['Location']).mean(numeric_only=True)['Rating']
rating.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
female_sales = sales.groupby(['City','Gender']).count()['Invoice ID']
female_sales
# Out:
# City     Gender
# Chicago  Female    143
#          Male      185
# Dallas   Female    179
#          Male      153
# NewYork  Female    179
#          Male      161
# Name: Invoice ID, dtype: int64

# %%
female_sales.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
spending = sales.groupby(['Gender']).mean(numeric_only=True)['Total']
spending.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
Members = sales.groupby(['Member']).mean(numeric_only=True)['Total']
Members.plot(kind='bar')
# Out:
# <Axes: xlabel='Member'>

# %%
product_list = sales.groupby('Category').count()['Invoice ID']
product_list.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
product_gender = sales.groupby(['Gender', 'Category']).count()['Invoice ID']
product_gender.unstack(level=1).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
product_gender = sales.groupby(['Gender', 'Category']).count()['Invoice ID']
product_gender.unstack(level=1).plot(kind='area')
# Out:
# <Axes: xlabel='Gender'>

# %%
product_gender = sales.groupby(['Gender', 'Category']).count()['Invoice ID']
product_gender.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
product_gender = sales.groupby(['Gender', 'Category']).count()['Invoice ID']
product_gender.unstack(level=0).plot(kind='pie', subplots=True, autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='Female'>, <Axes: ylabel='Male'>], dtype=object)

# %%
product_gender = sales.groupby(['Gender', 'Category']).count()['Invoice ID']
product_gender.unstack(level=0).plot(kind='area')
# Out:
# <Axes: xlabel='Category'>

# %%
sales.head(1)
# Out:
#    Invoice ID       Date   Time Gender    Location     City Member   Category  \
# 0   460489604  1/25/2018  16:46   Male  Brookfield  NewYork    Yes  Groceries
#
#    Price  Quantity  Total Payment  Rating  Day
# 0     30         1     30    Cash       2   25

# %%
sales['Month'] = pd.to_datetime(sales['Date']).dt.month
sales.head(1)
# Out:
#    Invoice ID       Date   Time Gender    Location     City Member   Category  \
# 0   460489604  1/25/2018  16:46   Male  Brookfield  NewYork    Yes  Groceries
#
#    Price  Quantity  Total Payment  Rating  Day  Month
# 0     30         1     30    Cash       2   25      1

# %%
sales_month = sales.groupby('Month').sum(numeric_only=True)['Total']
sales_month.plot(kind='bar').grid()

# %%
sales_month = sales.groupby('Month').sum(numeric_only=True)['Total']
sales_month.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
sales_month = sales.groupby('Month').sum(numeric_only=True)['Total']
sales_month.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Total'>

# %%
sales_month = sales.groupby('Month').sum(numeric_only=True)['Total']
sales_month.plot(kind='area')
# Out:
# <Axes: xlabel='Month'>

# %%
sales_month = sales.groupby('Month').sum(numeric_only=True)['Total']
sales_month.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>
